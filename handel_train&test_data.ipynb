# %% [markdown]
# # Handel the train data

# %% [markdown]
# # Import libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import dataset

# %%
train_df = pd.read_csv('train.csv')
train_df.head()
# Out:
#    id Sex  Length  Diameter  Height  Whole weight  Whole weight.1
# 0   0   F   0.550     0.430   0.150        0.7715          0.3285  \
# 1   1   F   0.630     0.490   0.145        1.1300          0.4580
# 2   2   I   0.160     0.110   0.025        0.0210          0.0055
# 3   3   M   0.595     0.475   0.150        0.9145          0.3755
# 4   4   I   0.555     0.425   0.130        0.7820          0.3695
#
#    Whole weight.2  Shell weight  Rings
# 0          0.1465        0.2400     11
# 1          0.2765        0.3200     11
# 2          0.0030        0.0050      6
# 3          0.2055        0.2500     10
# 4          0.1600        0.1975      9

# %%
train_df.drop('Sex',axis=1,inplace=True)
train_df.head()
# Out:
#    id  Length  Diameter  Height  Whole weight  Whole weight.1  Whole weight.2
# 0   0   0.550     0.430   0.150        0.7715          0.3285          0.1465  \
# 1   1   0.630     0.490   0.145        1.1300          0.4580          0.2765
# 2   2   0.160     0.110   0.025        0.0210          0.0055          0.0030
# 3   3   0.595     0.475   0.150        0.9145          0.3755          0.2055
# 4   4   0.555     0.425   0.130        0.7820          0.3695          0.1600
#
#    Shell weight  Rings
# 0        0.2400     11
# 1        0.3200     11
# 2        0.0050      6
# 3        0.2500     10
# 4        0.1975      9

# %%
train_df.isnull().sum()
# Out:
# id                0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Whole weight.1    0
# Whole weight.2    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90615 entries, 0 to 90614
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              90615 non-null  int64
#  1   Length          90615 non-null  float64
#  2   Diameter        90615 non-null  float64
#  3   Height          90615 non-null  float64
#  4   Whole weight    90615 non-null  float64
#  5   Whole weight.1  90615 non-null  float64
#  6   Whole weight.2  90615 non-null  float64
#  7   Shell weight    90615 non-null  float64
#  8   Rings           90615 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 6.2 MB

# %%
train_df.describe()
# Out:
#                  id        Length      Diameter        Height  Whole weight
# count  90615.000000  90615.000000  90615.000000  90615.000000  90615.000000  \
# mean   45307.000000      0.517098      0.401679      0.135464      0.789035
# std    26158.441658      0.118217      0.098026      0.038008      0.457671
# min        0.000000      0.075000      0.055000      0.000000      0.002000
# 25%    22653.500000      0.445000      0.345000      0.110000      0.419000
# 50%    45307.000000      0.545000      0.425000      0.140000      0.799500
# 75%    67960.500000      0.600000      0.470000      0.160000      1.067500
# max    90614.000000      0.815000      0.650000      1.130000      2.825500
#
#        Whole weight.1  Whole weight.2  Shell weight         Rings
# count    90615.000000    90615.000000  90615.000000  90615.000000
# mean         0.340778        0.169422      0.225898      9.696794
# std          0.204428        0.100909      0.130203      3.176221
# ...

# %%
train_df.shape
# Out:
# (90615, 9)

# %%
corr_matrix = train_df.corr()
print(corr_matrix)
# Out:
#                       id    Length  Diameter    Height  Whole weight
# id              1.000000  0.004724  0.004290  0.005916      0.005228  \
# Length          0.004724  1.000000  0.989732  0.916094      0.931449
# Diameter        0.004290  0.989732  1.000000  0.919618      0.933848
# Height          0.005916  0.916094  0.919618  1.000000      0.902344
# Whole weight    0.005228  0.931449  0.933848  0.902344      1.000000
# Whole weight.1  0.004203  0.909609  0.908466  0.861769      0.971249
# Whole weight.2  0.004878  0.913134  0.914668  0.886132      0.974319
# Shell weight    0.005887  0.911073  0.917871  0.904019      0.964201
# Rings           0.000938  0.623786  0.636832  0.665772      0.617274
#
#                 Whole weight.1  Whole weight.2  Shell weight     Rings
# id                    0.004203        0.004878      0.005887  0.000938
# Length                0.909609        0.913134      0.911073  0.623786
# ...

# %% [markdown]
# # Handel the test data

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#       id Sex  Length  Diameter  Height  Whole weight  Whole weight.1
# 0  90615   M   0.645     0.475   0.155        1.2380          0.6185  \
# 1  90616   M   0.580     0.460   0.160        0.9830          0.4785
# 2  90617   M   0.560     0.420   0.140        0.8395          0.3525
# 3  90618   M   0.570     0.490   0.145        0.8740          0.3525
# 4  90619   I   0.415     0.325   0.110        0.3580          0.1575
#
#    Whole weight.2  Shell weight
# 0          0.3125        0.3005
# 1          0.2195        0.2750
# 2          0.1845        0.2405
# 3          0.1865        0.2350
# 4          0.0670        0.1050

# %%
test_df.drop('Sex',axis=1,inplace=True)
test_df.head()
# Out:
#       id  Length  Diameter  Height  Whole weight  Whole weight.1
# 0  90615   0.645     0.475   0.155        1.2380          0.6185  \
# 1  90616   0.580     0.460   0.160        0.9830          0.4785
# 2  90617   0.560     0.420   0.140        0.8395          0.3525
# 3  90618   0.570     0.490   0.145        0.8740          0.3525
# 4  90619   0.415     0.325   0.110        0.3580          0.1575
#
#    Whole weight.2  Shell weight
# 0          0.3125        0.3005
# 1          0.2195        0.2750
# 2          0.1845        0.2405
# 3          0.1865        0.2350
# 4          0.0670        0.1050

# %% [markdown]
# # Columns in the dataset

# %%
train_df.columns
# Out:
# Index(['id', 'Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1',
#        'Whole weight.2', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # Exploratory data analysis(EDA)

# %%
sns.pairplot(train_df, vars=['Length', 'Diameter', 'Height', 'Whole weight.1','Whole weight.2', 'Shell weight', 'Rings'])
plt.show()

# %%
train_df["Rings"].hist(bins=10)
plt.title('Histogram of Rings')
plt.show()

# %%
train_df.boxplot(column="Rings")
plt.title('Boxplot of Rings')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(train_df.iloc[:, :-1].corr(),annot=True, square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(train_df['Length'], train_df['Rings'], c='blue')
plt.xlabel('Length of the abalone (mm)')
plt.ylabel('Number of rings')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(train_df['Height'], train_df['Rings'], c='black')
plt.xlabel('Height of the abalone (mm)')
plt.ylabel('Number of rings')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
#visualize the outliers
fig = plt.figure(figsize=(16,8))
ax = plt.axes(projection='3d')

ax.set_xlabel('Height of the abalone (mm)')
ax.set_ylabel('Length of the abalone (mm)')
ax.set_zlabel('Number of rings')
ax.scatter3D(train_df['Height'], train_df['Length'], train_df['Rings'], c='black')

plt.show()

# %%
# take look at the target in this case in the rings column
#df['Rings'].unique()
# Out:
# array([11,  6, 10,  9,  4,  8, 15,  7, 12, 20, 17, 13, 14,  5, 23,  3, 22,
#        16, 18, 19, 21, 25,  1, 29,  2, 27, 24, 26], dtype=int64)

# %%
#df['Rings'].value_counts().sort_index()
# Out:
# Rings
# 1        25
# 2        29
# 3       386
# 4      1402
# 5      2862
# 6      5411
# 7      9008
# 8     14499
# 9     17465
# 10    12464
# 11     8407
# 12     4719
# 13     4074
# 14     2507
# 15     2072
# 16     1439
# 17     1175
# 18      848
# 19      639
# 20      507
# 21      255
# 22      108
# 23      180
# 24       29
# 25       22
# 26       18
# 27       41
# 29       24
# Name: count, dtype: int64

# %% [markdown]
# We can see that the target is 1 to 28 but 28 is missing , so need to do the multi class classification

# %% [markdown]
# # Modelling the data

# %% [markdown]
# # Split the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X = train_df.drop(columns=['Rings'])
y = train_df['Rings']

# %%
print(X)
# Out:
#           id  Length  Diameter  Height  Whole weight  Whole weight.1
# 0          0   0.550     0.430   0.150        0.7715          0.3285  \
# 1          1   0.630     0.490   0.145        1.1300          0.4580
# 2          2   0.160     0.110   0.025        0.0210          0.0055
# 3          3   0.595     0.475   0.150        0.9145          0.3755
# 4          4   0.555     0.425   0.130        0.7820          0.3695
# ...      ...     ...       ...     ...           ...             ...
# 90610  90610   0.335     0.235   0.075        0.1585          0.0685
# 90611  90611   0.555     0.425   0.150        0.8790          0.3865
# 90612  90612   0.435     0.330   0.095        0.3215          0.1510
# 90613  90613   0.345     0.270   0.075        0.2000          0.0980
# 90614  90614   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight
# 0              0.1465        0.2400
# 1              0.2765        0.3200
# ...

# %%
X.shape
# Out:
# (90615, 8)

# %%
print(y)
# Out:
# 0        11
# 1        11
# 2         6
# 3        10
# 4         9
#          ..
# 90610     6
# 90611     9
# 90612     6
# 90613     6
# 90614     8
# Name: Rings, Length: 90615, dtype: int64

# %%
y.shape
# Out:
# (90615,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
l_reg = LinearRegression()

l_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
l_reg.coef_
# Out:
# array([-8.19366920e-07, -2.37097423e+00,  9.59405771e+00,  2.25720197e+01,
#         3.98695489e+00, -1.61993289e+01, -6.43637114e+00,  2.06699402e+01])

# %%
l_reg.intercept_
# Out:
# 2.845814545078757

# %%
l_reg.score(X_train, y_train)
# Out:
# 0.5987963670809109

# %%
pred = l_reg.predict(X_test)

# %%
plt.scatter(pred, y_test)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual VS Predicted")
# Out:
# Text(0.5, 1.0, 'Actual VS Predicted')

# %%
pred.shape
# Out:
# (27185,)

# %%
PRED = l_reg.predict(X_test)
PRED
# Out:
# array([10.62622736, 11.32520547,  7.86186823, ...,  9.890864  ,
#         8.68524181,  6.05335243])

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, pred)
print('R2 score is {}'.format(r2))
# Out:
# R2 score is 0.6005972850775405

# %%
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, pred)))
print('RMSE is {:.2f}.'.format(rmse))
# Out:
# RMSE is 2.01.

# %% [markdown]
# # XGBoost

# %%
import xgboost
classifier = xgboost.XGBRegressor()
classifier.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
reg = RandomForestRegressor(n_jobs=-1)
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
from sklearn.metrics import mean_squared_log_error

# %%
y_pred = reg.predict(X_test)
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))
print("RMSLE: ", rmsle)
# Out:
# RMSLE:  0.15560539273965357

# %%
y_pred
# Out:
# array([ 9.99, 12.11,  8.7 , ..., 11.07,  9.41,  5.88])

# %%
from sklearn.ensemble import GradientBoostingRegressor


model = GradientBoostingRegressor()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE) on Testing Data:", mse)
# Out:
# Mean Squared Error (MSE) on Testing Data: 3.5540755023682467

# %%
predictions = model.predict(test_df)
subm_df = pd.DataFrame({'id': test_df['id'], 'Rings':predictions})
subm_df.to_csv('sample_submission.csv',index=False)

# %%
subm_df.head()
# Out:
#       id      Rings
# 0  90615   9.436609
# 1  90616   9.881625
# 2  90617  10.275406
# 3  90618  10.148623
# 4  90619   7.798731
